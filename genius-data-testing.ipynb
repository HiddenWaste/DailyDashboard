# %% [markdown]
# # Testing With Genius API Data

# %% [markdown]
# Mainly doing this as I am heavily limited in monthly requests to this API, and this will help me minimize the amount of requests I make versus the formatting and coding benefits I will get working with this data.

# %%
import requests
import json
import pandas as pd

# %%
# Constants (Keys and such)
GENIUS_ARTIST_CHART_URL = "https://genius-song-lyrics1.p.rapidapi.com/chart/artists/"
GENIUS_ARTIST_CHART_QUERYSTRING = {"time_period":"week","per_page":"15","page":"1"}	# ID to retrive artist chart from Genius API
X_RAPIDAPI_KEY = "88d85341a3msh6a285814de5ffc0p10d2d5jsnd07b4d6f6f15"	# RapidAPI key Constant

# %%
# Function for genius artist charts
def get_artist_chart(url, querystring):
    headers = {
        "x-rapidapi-key": X_RAPIDAPI_KEY,	# RapidAPI key
        "x-rapidapi-host": "genius-song-lyrics1.p.rapidapi.com"					# RapidAPI host (Genius API)
    }

    response = requests.get(url, headers=headers, params=querystring)
    response_json = response.json()
    return response_json

# %%
# Get the artist chart from the Genius API
genius_artist_chart = get_artist_chart(GENIUS_ARTIST_CHART_URL, GENIUS_ARTIST_CHART_QUERYSTRING)

# Print the entire response JSON for debugging
print(json.dumps(genius_artist_chart, indent=4))
# Out:
# {
#     "chart_items": [
#         {
#             "_type": "chart_item",
#             "type": "artist",
#             "item": {
#                 "_type": "artist",
#                 "api_path": "/artists/1507735",
#                 "header_image_url": "https://images.genius.com/e5afba664f84f0cadba65e3231dd57c7.1000x495x1.png",
#                 "id": 1507735,
#                 "image_url": "https://images.genius.com/086f5809e96b133dd536982629e5844b.1000x1000x1.png",
#                 "index_character": "g",
#                 "is_meme_verified": false,
#                 "is_verified": false,
#                 "name": "Genius Romanizations",
#                 "slug": "Genius-romanizations",
#                 "url": "https://genius.com/artists/Genius-romanizations"
#             }
#         },
#         {
#             "_type": "chart_item",
#             "type": "artist",
#             "item": {
#                 "_type": "artist",
#                 "api_path": "/artists/196943",
# ...

# %%
# Initialize an empty list to store the filtered artist information
artist_list = []

# Define the names of artists to filter out
artists_to_filter = {"Genius Romanizations", 
                     "Genius English Translations", 
                     "Genius Traducciones al Español",
                     "Genius Brasil Traduções",
                     "Genius Türkçe Çeviri",
                     "Genius Français Traductions",}

# Extract artist details from the response
for chart_item in genius_artist_chart.get('chart_items', []):
    artist = chart_item.get('item', {})
    
    artist_info = {
        "name": artist.get('name'),
        "header_image_url": artist.get('header_image_url'),
        "url": artist.get('url')
    }
    # Only add artist to the list if their name is not in the filter list
    if artist_info['name'] not in artists_to_filter:
        artist_list.append(artist_info)

# %%
### DEBUGGING CELL

i = 0	# Rank iterator for the artists

# Print the filtered artist list
for artist in artist_list:
    # Print details for debugging
    print(f"Rank: {i+1}")										# Rank of the artist
    print(f"Name: {artist['name']}")							# Name of the artist
    print(f"Header Image URL: {artist['header_image_url']}")	# URL of the artist's header image
    print(f"URL: {artist['url']}")								# URL of the artist's Genius page
    print("\n")													# Newline for separation		
    i += 1														# Increment the rank iterator
# Out:
# Rank: 1
# Name: Eminem
# Header Image URL: https://images.genius.com/7879bf220b8614a7fe4617006f132a92.1000x391x1.png
# URL: https://genius.com/artists/Eminem
#
#
# Rank: 2
# Name: Taylor Swift
# Header Image URL: https://images.genius.com/1290896984554842b40f2450be157203.1000x333x1.jpg
# URL: https://genius.com/artists/Taylor-swift
#
#
# Rank: 3
# Name: NIKI
# Header Image URL: https://images.genius.com/2b12b2602dd2fee872c3cef485db60a6.1000x333x1.jpg
# URL: https://genius.com/artists/Niki
#
#
# Rank: 4
# Name: Kendrick Lamar
# Header Image URL: https://images.genius.com/4167280809fae642bf5093ead523a431.900x900x1.jpg
# URL: https://genius.com/artists/Kendrick-lamar
#
#
# Rank: 5
# Name: Drake
# Header Image URL: https://images.genius.com/451b30392a74ffed2233c1834e80fc68.1000x562x1.jpg
# URL: https://genius.com/artists/Drake
#
#
# Rank: 6
# Name: ¥$, Kanye West & Ty Dolla $ign
# Header Image URL: https://images.genius.com/4add2e019e10b4d7d866d4f71977a52d.1000x439x1.webp
# ...

# %% [markdown]
# # Formating Begins!!
#
# First we create a dataframe for this artist data!

# %%
artist_df = pd.DataFrame(artist_list)
print(artist_df)
# Out:
#                               name  \
# 0                           Eminem
# 1                     Taylor Swift
# 2                             NIKI
# 3                   Kendrick Lamar
# 4                            Drake
# 5   ¥$, Kanye West & Ty Dolla $ign
# 6                       Kanye West
# 7                      Post Malone
# 8                     ​beabadoobee
# 9                           Hozier
# 10                    Lana Del Rey
#
#                                      header_image_url  \
# 0   https://images.genius.com/7879bf220b8614a7fe46...
# 1   https://images.genius.com/1290896984554842b40f...
# 2   https://images.genius.com/2b12b2602dd2fee872c3...
# 3   https://images.genius.com/4167280809fae642bf50...
# 4   https://images.genius.com/451b30392a74ffed2233...
# 5   https://images.genius.com/4add2e019e10b4d7d866...
# 6   https://images.genius.com/f860375e040d0478339e...
# 7   https://images.genius.com/1cc70a5e8d2d4c7a1663...
# ...
